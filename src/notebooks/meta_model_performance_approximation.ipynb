# %%
import polars as pl
import lightgbm as lgb

from datetime import datetime

from src.util.constants import DATA_PATH
from src.util.common import mean_grouped_spearman_correlation

# %%
df_meta_model = pl.read_parquet(f"{DATA_PATH}/folds/df_meta_model.parquet")
df_meta_model = df_meta_model.drop([col for col in df_meta_model.columns if "target_" in col] + ["data_type", 'id'])

# %%
fixed_parameters = {
    'objective': 'regression',
    'metric': 'None',
    "n_jobs": 12,  # current number of cores on my Mac - set this to hardware cores, not virtual threads
    "subsample_freq": 1,
    "verbose": -1
}

num_boost_round_space = [10, 50, 200]
num_leaves_space = [2**(x*2) - 1 for x in range(2, 7)]

# %%
df_result = pl.DataFrame()

for num_boost_round in num_boost_round_space:
    for num_leaves in num_leaves_space:

        parameters = {
            **fixed_parameters,
            'num_leaves': num_leaves,
            'num_boost_round': num_boost_round
        }

        corr = []
        for fold in range(3):
            df_train = pl.read_parquet(f'{DATA_PATH}/folds/df_train_{fold}.parquet')
            df_validate = pl.read_parquet(f'{DATA_PATH}/folds/df_validate_{fold}.parquet')
            feature_names = [x for x in df_train.columns if 'feature' in x]

            lgb_train = lgb.Dataset(df_train[feature_names].to_numpy(), label=df_train['target'].to_numpy())

            model = lgb.train(
                params=parameters,
                train_set=lgb_train,
                num_boost_round=parameters['num_boost_round']
            )

            corr.append(mean_grouped_spearman_correlation(
                pl.Series(model.predict(df_validate[feature_names].to_numpy())),
                df_validate['target'],
                df_validate['era']
            ))

            if fold == 2:
                df_meta_model = df_meta_model.with_columns(
                    prediction=pl.Series(model.predict(df_meta_model[feature_names].to_numpy()))
                )
                corr_mm_set = mean_grouped_spearman_correlation(
                    df_meta_model['prediction'].to_numpy(),
                    df_meta_model['target'],
                    df_meta_model['era'].to_numpy()
                )
                corr_w_mm = df_meta_model.select(
                    pl.corr("prediction", "numerai_meta_model", method="spearman").over('era', mapping_strategy='explode')
                ).mean()[0, 0]

            print(f'{datetime.now().strftime("%H:%M:%S")} . . . Training and evaluating model for num_leaves={num_leaves}, num_boost_round={num_boost_round}, and fold {fold} done.')

        df_result = df_result.vstack(
            pl.DataFrame({'corr_0': corr[0], 'corr_1': corr[1], 'corr_2': corr[2], 'corr_mm_set': corr_mm_set, 'corr_w_mm': corr_w_mm})  # noqa: is existence is ensured by loop
        )
# Out:
# 22:39:25 . . . Training and evaluating model for num_leaves=15, num_boost_round=10, and fold 0 done.
# 22:42:17 . . . Training and evaluating model for num_leaves=15, num_boost_round=10, and fold 1 done.
# 22:47:06 . . . Training and evaluating model for num_leaves=15, num_boost_round=10, and fold 2 done.
# shape: (1, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 22:48:57 . . . Training and evaluating model for num_leaves=63, num_boost_round=10, and fold 0 done.
# 22:51:39 . . . Training and evaluating model for num_leaves=63, num_boost_round=10, and fold 1 done.
# 22:56:26 . . . Training and evaluating model for num_leaves=63, num_boost_round=10, and fold 2 done.
# shape: (2, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 22:58:25 . . . Training and evaluating model for num_leaves=255, num_boost_round=10, and fold 0 done.
# 23:01:44 . . . Training and evaluating model for num_leaves=255, num_boost_round=10, and fold 1 done.
# 23:06:38 . . . Training and evaluating model for num_leaves=255, num_boost_round=10, and fold 2 done.
# shape: (3, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 23:08:47 . . . Training and evaluating model for num_leaves=1023, num_boost_round=10, and fold 0 done.
# 23:12:11 . . . Training and evaluating model for num_leaves=1023, num_boost_round=10, and fold 1 done.
# 23:17:14 . . . Training and evaluating model for num_leaves=1023, num_boost_round=10, and fold 2 done.
# shape: (4, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 23:19:45 . . . Training and evaluating model for num_leaves=4095, num_boost_round=10, and fold 0 done.
# 23:23:34 . . . Training and evaluating model for num_leaves=4095, num_boost_round=10, and fold 1 done.
# 23:29:17 . . . Training and evaluating model for num_leaves=4095, num_boost_round=10, and fold 2 done.
# shape: (5, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 23:32:43 . . . Training and evaluating model for num_leaves=15, num_boost_round=50, and fold 0 done.
# 23:37:30 . . . Training and evaluating model for num_leaves=15, num_boost_round=50, and fold 1 done.
# 23:44:50 . . . Training and evaluating model for num_leaves=15, num_boost_round=50, and fold 2 done.
# shape: (6, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ 0.021804 ┆ 0.027286 ┆ 0.015099 ┆ 0.019187    ┆ 0.581012  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 23:48:49 . . . Training and evaluating model for num_leaves=63, num_boost_round=50, and fold 0 done.
# 23:54:27 . . . Training and evaluating model for num_leaves=63, num_boost_round=50, and fold 1 done.
# 00:02:15 . . . Training and evaluating model for num_leaves=63, num_boost_round=50, and fold 2 done.
# shape: (7, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ 0.021804 ┆ 0.027286 ┆ 0.015099 ┆ 0.019187    ┆ 0.581012  │
# │ 0.021525 ┆ 0.028166 ┆ 0.016439 ┆ 0.020987    ┆ 0.576359  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 00:06:36 . . . Training and evaluating model for num_leaves=255, num_boost_round=50, and fold 0 done.
# 00:15:03 . . . Training and evaluating model for num_leaves=255, num_boost_round=50, and fold 1 done.
# 00:23:38 . . . Training and evaluating model for num_leaves=255, num_boost_round=50, and fold 2 done.
# shape: (8, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ 0.021804 ┆ 0.027286 ┆ 0.015099 ┆ 0.019187    ┆ 0.581012  │
# │ 0.021525 ┆ 0.028166 ┆ 0.016439 ┆ 0.020987    ┆ 0.576359  │
# │ 0.019339 ┆ 0.022206 ┆ 0.015936 ┆ 0.019563    ┆ 0.513492  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 00:28:46 . . . Training and evaluating model for num_leaves=1023, num_boost_round=50, and fold 0 done.
# 00:36:13 . . . Training and evaluating model for num_leaves=1023, num_boost_round=50, and fold 1 done.
# 00:45:50 . . . Training and evaluating model for num_leaves=1023, num_boost_round=50, and fold 2 done.
# shape: (9, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ 0.021804 ┆ 0.027286 ┆ 0.015099 ┆ 0.019187    ┆ 0.581012  │
# │ 0.021525 ┆ 0.028166 ┆ 0.016439 ┆ 0.020987    ┆ 0.576359  │
# │ 0.019339 ┆ 0.022206 ┆ 0.015936 ┆ 0.019563    ┆ 0.513492  │
# │ 0.015855 ┆ 0.017679 ┆ 0.01279  ┆ 0.016526    ┆ 0.408164  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 01:02:35 . . . Training and evaluating model for num_leaves=4095, num_boost_round=50, and fold 0 done.
# 01:12:29 . . . Training and evaluating model for num_leaves=4095, num_boost_round=50, and fold 1 done.
# 01:24:52 . . . Training and evaluating model for num_leaves=4095, num_boost_round=50, and fold 2 done.
# shape: (10, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ 0.021804 ┆ 0.027286 ┆ 0.015099 ┆ 0.019187    ┆ 0.581012  │
# │ 0.021525 ┆ 0.028166 ┆ 0.016439 ┆ 0.020987    ┆ 0.576359  │
# │ 0.019339 ┆ 0.022206 ┆ 0.015936 ┆ 0.019563    ┆ 0.513492  │
# │ 0.015855 ┆ 0.017679 ┆ 0.01279  ┆ 0.016526    ┆ 0.408164  │
# │ 0.011138 ┆ 0.015593 ┆ 0.010722 ┆ 0.014619    ┆ 0.308282  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 01:35:37 . . . Training and evaluating model for num_leaves=15, num_boost_round=200, and fold 0 done.
# 01:49:59 . . . Training and evaluating model for num_leaves=15, num_boost_round=200, and fold 1 done.
# 02:06:19 . . . Training and evaluating model for num_leaves=15, num_boost_round=200, and fold 2 done.
# shape: (11, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ …        ┆ …        ┆ …        ┆ …           ┆ …         │
# │ 0.021525 ┆ 0.028166 ┆ 0.016439 ┆ 0.020987    ┆ 0.576359  │
# │ 0.019339 ┆ 0.022206 ┆ 0.015936 ┆ 0.019563    ┆ 0.513492  │
# │ 0.015855 ┆ 0.017679 ┆ 0.01279  ┆ 0.016526    ┆ 0.408164  │
# │ 0.011138 ┆ 0.015593 ┆ 0.010722 ┆ 0.014619    ┆ 0.308282  │
# │ 0.028196 ┆ 0.030974 ┆ 0.018952 ┆ 0.022904    ┆ 0.684535  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 02:16:21 . . . Training and evaluating model for num_leaves=63, num_boost_round=200, and fold 0 done.
# 02:30:25 . . . Training and evaluating model for num_leaves=63, num_boost_round=200, and fold 1 done.
# 02:48:22 . . . Training and evaluating model for num_leaves=63, num_boost_round=200, and fold 2 done.
# shape: (12, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ …        ┆ …        ┆ …        ┆ …           ┆ …         │
# │ 0.019339 ┆ 0.022206 ┆ 0.015936 ┆ 0.019563    ┆ 0.513492  │
# │ 0.015855 ┆ 0.017679 ┆ 0.01279  ┆ 0.016526    ┆ 0.408164  │
# │ 0.011138 ┆ 0.015593 ┆ 0.010722 ┆ 0.014619    ┆ 0.308282  │
# │ 0.028196 ┆ 0.030974 ┆ 0.018952 ┆ 0.022904    ┆ 0.684535  │
# │ 0.026513 ┆ 0.027771 ┆ 0.017097 ┆ 0.016311    ┆ 0.629023  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 03:00:18 . . . Training and evaluating model for num_leaves=255, num_boost_round=200, and fold 0 done.
# 03:15:40 . . . Training and evaluating model for num_leaves=255, num_boost_round=200, and fold 1 done.
# 03:35:47 . . . Training and evaluating model for num_leaves=255, num_boost_round=200, and fold 2 done.
# shape: (13, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ …        ┆ …        ┆ …        ┆ …           ┆ …         │
# │ 0.015855 ┆ 0.017679 ┆ 0.01279  ┆ 0.016526    ┆ 0.408164  │
# │ 0.011138 ┆ 0.015593 ┆ 0.010722 ┆ 0.014619    ┆ 0.308282  │
# │ 0.028196 ┆ 0.030974 ┆ 0.018952 ┆ 0.022904    ┆ 0.684535  │
# │ 0.026513 ┆ 0.027771 ┆ 0.017097 ┆ 0.016311    ┆ 0.629023  │
# │ 0.021416 ┆ 0.021288 ┆ 0.01494  ┆ 0.018944    ┆ 0.516998  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 03:51:14 . . . Training and evaluating model for num_leaves=1023, num_boost_round=200, and fold 0 done.
# 04:29:08 . . . Training and evaluating model for num_leaves=1023, num_boost_round=200, and fold 1 done.
# 04:54:47 . . . Training and evaluating model for num_leaves=1023, num_boost_round=200, and fold 2 done.
# shape: (14, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ …        ┆ …        ┆ …        ┆ …           ┆ …         │
# │ 0.011138 ┆ 0.015593 ┆ 0.010722 ┆ 0.014619    ┆ 0.308282  │
# │ 0.028196 ┆ 0.030974 ┆ 0.018952 ┆ 0.022904    ┆ 0.684535  │
# │ 0.026513 ┆ 0.027771 ┆ 0.017097 ┆ 0.016311    ┆ 0.629023  │
# │ 0.021416 ┆ 0.021288 ┆ 0.01494  ┆ 0.018944    ┆ 0.516998  │
# │ 0.018578 ┆ 0.016356 ┆ 0.011892 ┆ 0.016477    ┆ 0.40262   │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘
# 05:18:07 . . . Training and evaluating model for num_leaves=4095, num_boost_round=200, and fold 0 done.
# 05:47:07 . . . Training and evaluating model for num_leaves=4095, num_boost_round=200, and fold 1 done.
# 06:22:49 . . . Training and evaluating model for num_leaves=4095, num_boost_round=200, and fold 2 done.
# shape: (15, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.013796 ┆ 0.022798 ┆ 0.009786 ┆ 0.010884    ┆ 0.420501  │
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.01157     ┆ 0.444974  │
# │ 0.013933 ┆ 0.021974 ┆ 0.010036 ┆ 0.015197    ┆ 0.408981  │
# │ 0.008845 ┆ 0.010829 ┆ 0.011243 ┆ 0.009653    ┆ 0.331365  │
# │ 0.009065 ┆ 0.009737 ┆ 0.008064 ┆ 0.012906    ┆ 0.229321  │
# │ …        ┆ …        ┆ …        ┆ …           ┆ …         │
# │ 0.028196 ┆ 0.030974 ┆ 0.018952 ┆ 0.022904    ┆ 0.684535  │
# │ 0.026513 ┆ 0.027771 ┆ 0.017097 ┆ 0.016311    ┆ 0.629023  │
# │ 0.021416 ┆ 0.021288 ┆ 0.01494  ┆ 0.018944    ┆ 0.516998  │
# │ 0.018578 ┆ 0.016356 ┆ 0.011892 ┆ 0.016477    ┆ 0.40262   │
# │ 0.013328 ┆ 0.015919 ┆ 0.010367 ┆ 0.01323     ┆ 0.313572  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘

# %%
df_result.median()
# Out:
# shape: (1, 5)
# ┌──────────┬──────────┬──────────┬─────────────┬───────────┐
# │ corr_0   ┆ corr_1   ┆ corr_2   ┆ corr_mm_set ┆ corr_w_mm │
# │ ---      ┆ ---      ┆ ---      ┆ ---         ┆ ---       │
# │ f64      ┆ f64      ┆ f64      ┆ f64         ┆ f64       │
# ╞══════════╪══════════╪══════════╪═════════════╪═══════════╡
# │ 0.016831 ┆ 0.021903 ┆ 0.011901 ┆ 0.016311    ┆ 0.420501  │
# └──────────┴──────────┴──────────┴─────────────┴───────────┘

# %%
performance_ratio_median = mean_grouped_spearman_correlation(
    df_meta_model['numerai_meta_model'],
    df_meta_model['target'], df_meta_model['era']
) / df_result['corr_mm_set'].median()
print(performance_ratio_median)
# Out:
# 2.210682073090773

# %%
print(df_result.median()[0, 0:3] * performance_ratio_median)
# Out:
# shape: (1, 3)
# ┌──────────┬─────────┬─────────┐
# │ corr_0   ┆ corr_1  ┆ corr_2  │
# │ ---      ┆ ---     ┆ ---     │
# │ f64      ┆ f64     ┆ f64     │
# ╞══════════╪═════════╪═════════╡
# │ 0.037209 ┆ 0.04842 ┆ 0.02631 │
# └──────────┴─────────┴─────────┘
